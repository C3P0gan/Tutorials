# %% [markdown]
# # Pré-processamento

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU
# Out:
# 2024-04-30 10:19:11.483922: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-30 10:19:11.484321: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-30 10:19:11.486606: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-30 10:19:11.515174: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 10:19:12.118956: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
passageiros = pd.read_csv('passageiros.csv')
passageiros.head()
# Out:
#          tempo  passageiros
# 0  1949.000000          112
# 1  1949.083333          118
# 2  1949.166667          132
# 3  1949.250000          129
# 4  1949.333333          121

# %%
plt.rcParams['figure.figsize'] = (10,6)
plt.rcParams['font.size'] = 22

# %%
sns.lineplot(x='tempo', y='passageiros', data=passageiros, label='dado_completo')
# Out:
# <Axes: xlabel='tempo', ylabel='passageiros'>

# %%
sc = StandardScaler()
sc.fit(passageiros)
# Out:
# StandardScaler()

# %%
dado_escalado = sc.transform(passageiros)

# %%
x = dado_escalado[:,0]
y = dado_escalado[:,1]

# %%
plt.xlabel('data')
plt.ylabel('passageiros')
sns.lineplot(x=x, y=y, label='dado_escalado')
# Out:
# <Axes: xlabel='data', ylabel='passageiros'>

# %%
tamanho_treino = int(len(passageiros) * 0.9)
tamanho_teste = len(passageiros) - tamanho_treino

# %%
x_treino = x[0:tamanho_treino]
y_treino = y[0:tamanho_treino]

# %%
x_teste = x[tamanho_treino:len(passageiros)]
y_teste = y[tamanho_treino:len(passageiros)]

# %%
plt.xlabel('data')
plt.ylabel('passageiros')
sns.lineplot(x=x_treino, y=y_treino, label='treino')
sns.lineplot(x=x_teste, y=y_teste, label='teste')
# Out:
# <Axes: xlabel='data', ylabel='passageiros'>

# %% [markdown]
# # 02.Regressão

# %% [markdown]
# $ z = Wx + b $
#
# $ a(z) = Cz $

# %%
regressor = Sequential()
regressor.add(Dense(1, input_dim=1, kernel_initializer='Ones', use_bias=False, activation='linear'))
# Out:
# /home/cristoffer_pogan/Documents/dev/Tutorials/Alura/Formacao_Machine_Learning_Avancada/Deep_Learning_Previsao_com_Keras/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-04-30 10:19:13.736328: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
regressor.compile(loss='mean_squared_error', optimizer='adam')

# %%
regressor.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             1 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1 (4.00 B)
#  Trainable params: 1 (4.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
regressor.fit(x_treino, y_treino)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1343

# %%
y_predict = regressor.predict(x_treino)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
sns.lineplot(x=x_treino, y=y_treino, label='treino')
sns.lineplot(x=x_treino, y=y_predict[:,0], label='ajuste_treino')
# Out:
# <Axes: >

# %%
d = {'tempo': x_treino, 'passageiros': y_predict[:,0]}

# %%
resultados = pd.DataFrame(data=d)
resultados
# Out:
#         tempo  passageiros
# 0   -1.720064    -1.712531
# 1   -1.696007    -1.688579
# 2   -1.671950    -1.664628
# 3   -1.647894    -1.640676
# 4   -1.623837    -1.616725
# ..        ...          ...
# 124  1.262984     1.257452
# 125  1.287041     1.281404
# 126  1.311098     1.305356
# 127  1.335155     1.329307
# 128  1.359212     1.353258
#
# [129 rows x 2 columns]

# %%
resultado_transf = sc.inverse_transform(resultados)
resultado_transf = pd.DataFrame(resultado_transf)
resultado_transf.columns = ['tempo', 'passageiros']

# %%
sns.lineplot(x='tempo', y='passageiros', data=passageiros, label='dado_completo')
sns.lineplot(x='tempo', y='passageiros', data=resultado_transf, label='ajuste_treino')
# Out:
# <Axes: xlabel='tempo', ylabel='passageiros'>

# %%
y_predict_teste = regressor.predict(x_teste)
d = {'tempo': x_teste, 'passageiros': y_predict_teste[:,0]}
resultado_teste = pd.DataFrame(data=d)
resultado_transf_teste = sc.inverse_transform(resultado_teste)
resultado_transf_teste = pd.DataFrame(resultado_transf_teste)
resultado_transf_teste.columns = ['tempo', 'passageiros']
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
sns.lineplot(x='tempo', y='passageiros', data=passageiros, label='dado_completo')
sns.lineplot(x='tempo', y='passageiros', data=resultado_transf, label='ajuste_treino')
sns.lineplot(x='tempo', y='passageiros', data=resultado_transf_teste, label='previsão')
# Out:
# <Axes: xlabel='tempo', ylabel='passageiros'>

# %%
regressor2 = Sequential()
regressor2.add(Dense(8, input_dim=1, kernel_initializer='random_uniform', activation='linear', use_bias=False))
regressor2.add(Dense(8, kernel_initializer='random_uniform', activation='sigmoid', use_bias=False))
regressor2.add(Dense(1, kernel_initializer='random_uniform', activation='sigmoid', use_bias=False))
regressor2.compile(loss='mean_squared_error', optimizer='adam')
regressor2.summary()
# Out:
# /home/cristoffer_pogan/Documents/dev/Tutorials/Alura/Formacao_Machine_Learning_Avancada/Deep_Learning_Previsao_com_Keras/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 8)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80 (320.00 B)
#  Trainable params: 80 (320.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
regressor2.fit(x_treino, y_treino, epochs=500)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 1.3000
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 1.1570
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 1.1256
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 1.2286
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 1.2476
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 1.1452
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 1.2269
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 1.1473
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 1.2515
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 1.1562
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 1.2051
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 1.1535
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 1.1657
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 1.2209
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 1.1043
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 1.1499
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 1.2467
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 1.1487
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 1.1239
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 1.1567
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 1.0930
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 1.2053
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 1.1622
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 1.0804
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 1.0648
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 1.1285
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 1.2092
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 1.1741
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.9879
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 1.1025
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 1.1105
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 1.1083
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 1.0278
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 1.0658
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 1.0396
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 1.0385
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 0.9897
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 1.0013
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 1.0445
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 1.0259
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.9962
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 0.9469
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.9931
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.9130
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.9589
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.8951
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.9479
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.9671
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.8777
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.9008
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.8963
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.9302
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.8828
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.8672
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.8620
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.8695
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.8808
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 0.8435
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.8040
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 0.8302
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 0.7986
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.8115
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.8660
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.8097
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.8557
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.7721
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.7669
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.7663
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.8082
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.7415
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 0.8045
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.8297
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.7498
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.7727
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.7528
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.7367
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.7701
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.8042
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.7452
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.7543
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.7543
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.7554
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.7629
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.7480
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.7150
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.6839
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.7170
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.7397
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.6963
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.7370
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.7533
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.7206
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.7524
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.7133
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.7399
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.6890
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.6888
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.7169
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.7430
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.7426
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.7427
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.7181
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.7167
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.7142
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.6994
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.6658
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.7124
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.6778
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.7127
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6820
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 0.6529
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.7194
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.6965
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 0.7496
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.6724
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.6791
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 0.7208
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.7185
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.6727
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6582
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.7113
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.6363
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6835
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.6278
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.7080
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.7522
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.6651
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.6306
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.6632
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.7213
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.6377
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.6600
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.7116
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.7160
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.6339
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.6785
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.6465
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.6422
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.7164
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.6408
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - loss: 0.6236
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.6717
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.6800
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.6462
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 0.6533
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 0.6666
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.6358
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.6330
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.6342
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.6875
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.6553
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.6731
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.6771
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.6437
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.6468
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6988
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7282
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 0.6166
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.6546
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.6112
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.6097
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6636
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.6398
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.6241
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.6767
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.7014
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.6719
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.6484
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.6562
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.6462
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 0.6240
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.6715
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 0.6522
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.6564
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 0.6264
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.6624
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.6151
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.7027
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.6748
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 0.6228
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 0.6484
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.6498
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.6396
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.6570
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.6845
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.6532
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.6330
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.6282
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.6227
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.6402
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.6619
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 0.6455
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.6072
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.6319
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6641
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.7109
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.7095
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.6412
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.6123
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.6206
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.6308
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.7098
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.6682
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.6231
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.6803
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.6383
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.6435
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 0.6727
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.5932
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.6724
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 0.6174
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.6116
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.5996
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.6969
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.7010
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.6675
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.6731
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.6421
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.6188
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.6623
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.6195
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.6274
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.6467
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.6150
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.6522
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.6607
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.6724
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.6389
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 0.6190
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 0.6239
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6529
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.6207
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.5919
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 0.6083
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.6044
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6643
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.6224
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.6590
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.6456
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 0.6448
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.7169
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.6134
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.6712
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 0.6186
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.6512
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.6385
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.6266
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.6213
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - loss: 0.6319
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.6878
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.7137
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.6330
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.6449
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.5984
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.6290
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.6781
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.6517
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.6491
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.6284
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.6200
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.6599
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.6975
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.6179
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.6240
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.5992
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.6128
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.5769
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.5609
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.6473
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.6479
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.6110
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.6591
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.6641
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.6493
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.6560
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.6093
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.5889
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.6598
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.6207
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.6051
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.6573
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.7226
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.5844
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.6129
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.6203
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.6534
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.6534
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.6639
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.6594
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.6926
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.6328
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.6348
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.6070
# Epoch 294/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.6234
# Epoch 295/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.6367
# Epoch 296/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.6269
# Epoch 297/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6331
# Epoch 298/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.6545
# Epoch 299/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 0.6186
# Epoch 300/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 0.6064
# Epoch 301/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.6281
# Epoch 302/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.6058
# Epoch 303/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.5998
# Epoch 304/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 0.6452
# Epoch 305/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6269
# Epoch 306/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6668
# Epoch 307/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - loss: 0.6441
# Epoch 308/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 0.6200
# Epoch 309/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.6128
# Epoch 310/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.6790
# Epoch 311/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.6455
# Epoch 312/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.5986
# Epoch 313/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.6541
# Epoch 314/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.5995
# Epoch 315/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.6021
# Epoch 316/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.6002
# Epoch 317/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.6233
# Epoch 318/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.6387
# Epoch 319/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.6225
# Epoch 320/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.6665
# Epoch 321/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.6374
# Epoch 322/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.6415
# Epoch 323/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.6573
# Epoch 324/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.5796
# Epoch 325/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - loss: 0.5950
# Epoch 326/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.5853
# Epoch 327/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.6063
# Epoch 328/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.6962
# Epoch 329/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.6336
# Epoch 330/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.6457
# Epoch 331/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.6513
# Epoch 332/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 0.6378
# Epoch 333/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.6777
# Epoch 334/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.6273
# Epoch 335/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.6429
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.6172
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.6198
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.6524
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.6153
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.6332
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.7050
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6093
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 0.6666
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.6415
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.6443
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6270
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.6355
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - loss: 0.6597
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.6507
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.6227
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.5747
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.7110
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.6220
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.6376
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 0.6484
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.6470
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.6093
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.6718
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.6301
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.6211
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.6280
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.6404
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 0.6306
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.6103
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.6405
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.6979
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 0.5967
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.6781
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6230
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.5870
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.6291
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.6212
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.6508
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.6562
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 0.6346
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.7219
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.6039
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.5924
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.6679
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.6382
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.6547
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - loss: 0.6806
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.5652
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.6266
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.5727
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.6216
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.6254
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.5710
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.6204
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.6480
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6161
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.6257
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.5879
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.6538
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.6445
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.6647
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.6358
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.6528
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.6890
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.6219
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6365
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.6187
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.6540
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.6487
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.6063
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.6266
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6888
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 0.6090
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6245
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 0.6756
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.6572
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.6183
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.6110
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.6095
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.6265
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.6487
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.6218
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.6144
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 0.6140
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.6270
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - loss: 0.6423
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.6267
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.6146
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.6543
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.6440
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.5948
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.6659
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 0.6049
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.6564
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.6372
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 0.6363
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.5840
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6268
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.6500
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.6286
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.5778
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - loss: 0.6565
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.6277
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.6104
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 0.6128
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.6532
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.6533
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.5928
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.6077
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.6116
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.6087
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.6697
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.6208
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.6182
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.6001
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6053
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.6849
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.5988
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.6211
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.6230
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6209
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.6759
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.5911
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.6459
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.5773
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.6479
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.6034
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.6662
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.5957
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.6190
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.6090
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.6426
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.6642
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.6221
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - loss: 0.6391
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.6419
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 0.6245
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.6043
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.6286
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.5684
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.6249
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.6275
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 0.6013
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.6566
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.5941
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - loss: 0.6225
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 0.6239
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.6310
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.6331
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.6052
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.6024
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.6664
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.6469
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 0.6261
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.6591
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.6456
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.6382
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.6634
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.6206
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.5938
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.5953
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 0.6097
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.6055
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.5739
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.6809

# %%
y_predict = regressor2.predict(x_treino)
y_predict_teste = regressor2.predict(x_teste)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
sns.lineplot(x=x_treino, y=y_treino, label='treino')
sns.lineplot(x=x_teste, y=y_teste, label='teste')
sns.lineplot(x=x_treino, y=y_predict[:,0], label='ajuste_treino')
sns.lineplot(x=x_teste, y=y_predict_teste[:,0], label='previsão')
# Out:
# <Axes: >

# %% [markdown]
# $\Huge \sigma(z) = \frac{1}{1+e^{-z}} $

# %% [markdown]
# ## Atualização do pesos

# %% [markdown]
# No vídeo anterior utilizamos o otimizador Adam para ser responsável pela atualização dos pesos. Este algoritmo é exemplo de um método de gradiente descendente estocástico desenvolvido para ser computacionalmente eficiente.
# [Neste texto](https://cursos.alura.com.br/course/rede-neural-numpy/task/57827) eu explico como um algoritmo de gradiente descendente simples funciona.
#
# Em conjunto com o algoritmo de otimização precisamos utilizar uma função de custo que vai medir quanto a nossa estimativa é diferente do valor conhecido. O algoritmo de otimização busca minimizar o valor da função de custo. No problema estudado no curso estamos estimando o número de passageiros. Para minimizar a função de custo, o número de passageiros estimado deve ser o mais próximo possível do número de passageiros presentes nos dados de treino.
#
# [Neste link](https://www.tensorflow.org/api_docs/python/tf/keras/losses) você encontra diferentes funções de custo presentes no Keras. A função de custo de erro médio quadrático é uma das que é adequada para problemas de regressão.

# %% [markdown]
# # 03.Reformulando o problema

# %%
vetor = pd.DataFrame(y_treino)[0]

# %%
def separa_dados(vetor: pd.DataFrame, n_passos: int):
    x_novo, y_novo = [], []

    for i in range(n_passos, vetor.shape[0]):
        x_novo.append(list(vetor.loc[i - n_passos: i - 1]))
        y_novo.append(vetor.loc[i])
    
    x_novo, y_novo = np.array(x_novo), np.array(y_novo)
    return x_novo, y_novo

# %%
x_treino_novo, y_treino_novo = separa_dados(vetor, 1)

# %%
x_treino_novo[0:5]
# Out:
# array([[-1.40777884],
#        [-1.35759023],
#        [-1.24048348],
#        [-1.26557778],
#        [-1.33249593]])

# %%
y_treino_novo[0:5]
# Out:
# array([-1.35759023, -1.24048348, -1.26557778, -1.33249593, -1.21538918])

# %%
vetor2 = pd.DataFrame(y_teste)[0]
x_teste_novo, y_teste_novo = separa_dados(vetor2, 1)

# %%
regressor3 = Sequential([
    Dense(8, input_dim=1, kernel_initializer='ones', activation='linear', use_bias=False),
    Dense(64, kernel_initializer='random_uniform', activation='sigmoid', use_bias=False),
    Dense(1, kernel_initializer='random_uniform', activation='linear', use_bias=False)
])

regressor3.compile(loss='mean_squared_error', optimizer='adam')

regressor3.fit(x_treino_novo, y_treino_novo, epochs=100)
# Out:
# Epoch 1/100
# /home/cristoffer_pogan/Documents/dev/Tutorials/Alura/Formacao_Machine_Learning_Avancada/Deep_Learning_Previsao_com_Keras/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7591
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 0.7300
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.6809
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.7406
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.7243
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.7596
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.6942
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.6995
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.5508
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.5444
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.5493
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.4799
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.4941
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.4312
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.3918
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 0.3341
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3006
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.2628
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2017
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.1916
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.1813
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.1215
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.1228
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.0941
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0742
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.0721
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.0803
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0658
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.0709
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.0541
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.0549
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - loss: 0.0652
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.0569
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.0637
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 0.0629
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 0.0637
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0666
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.0654
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.0689
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0618
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.0655
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.0572
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.0677
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0607
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.0595
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.0608
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0610
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.0586
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.0552
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.0630
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.0648
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.0688
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - loss: 0.0641
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.0607
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.0638
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.0613
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.0529
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.0650
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.0653
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.0701
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0680
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 0.0574
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.0704
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.0628
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.0673
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.0714
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0608
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.0646
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.0527
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0661
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.0624
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.0620
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 0.0644
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.0623
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.0672
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - loss: 0.0646
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.0685
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0633
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 0.0618
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 0.0577
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.0583
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.0610
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.0619
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0587
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.0600
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.0696
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 0.0572
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.0589
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.0671
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.0605
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0614
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0605
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.0619
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.0629
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.0583
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.0657
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0640
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0664
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 0.0678
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.0684

# %%
y_predict_novo = regressor3.predict(x_treino_novo)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x72db30251e10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step

# %%
sns.lineplot(x='tempo', y=y_treino_novo, data=passageiros[1:129], label='treino')
sns.lineplot(x='tempo', y=pd.DataFrame(y_predict_novo)[0], data=passageiros[1:129], label='ajuste_treino')
# Out:
# <Axes: xlabel='tempo', ylabel='0'>

# %%
y_predict_teste_novo = regressor3.predict(x_teste_novo)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step

# %%
sns.lineplot(x='tempo', y=y_treino_novo, data=passageiros[1:129], label='treino')
sns.lineplot(x='tempo', y=pd.DataFrame(y_predict_novo)[0], data=passageiros[1:129], label='ajuste_treino')
sns.lineplot(x='tempo', y=y_teste_novo, data=passageiros[130:144], label='teste')
sns.lineplot(x='tempo', y=pd.DataFrame(y_predict_teste_novo)[0].values, data=passageiros[130:144], label='previsão')
# Out:
# <Axes: xlabel='tempo', ylabel='0'>

# %%
x_treino_novo, y_treino_novo = separa_dados(vetor, 4)

# %%
x_treino_novo[0:5]
# Out:
# array([[-1.40777884, -1.35759023, -1.24048348, -1.26557778],
#        [-1.35759023, -1.24048348, -1.26557778, -1.33249593],
#        [-1.24048348, -1.26557778, -1.33249593, -1.21538918],
#        [-1.26557778, -1.33249593, -1.21538918, -1.10664719],
#        [-1.33249593, -1.21538918, -1.10664719, -1.10664719]])

# %%
y_treino_novo[0:5]
# Out:
# array([-1.33249593, -1.21538918, -1.10664719, -1.10664719, -1.20702441])

# %%
x_teste_novo, y_teste_novo = separa_dados(vetor2, 4)

# %%
regressor4 = Sequential([
    Dense(8, input_dim=4, kernel_initializer='ones', activation='linear', use_bias=False),
    Dense(64, kernel_initializer='random_uniform', activation='sigmoid', use_bias=False),
    Dense(1, kernel_initializer='random_uniform', activation='linear', use_bias=False)
])

regressor4.compile(loss='mean_squared_error', optimizer='adam')

regressor4.fit(x_treino_novo, y_treino_novo, epochs=300)
# Out:
# Epoch 1/300
# /home/cristoffer_pogan/Documents/dev/Tutorials/Alura/Formacao_Machine_Learning_Avancada/Deep_Learning_Previsao_com_Keras/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.7262
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 0.6986
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.5337
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.6105
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.4837
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 0.3732
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 0.3759
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.3906
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.2727
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.2608
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.2023
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.1705
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.1799
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1722
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 0.1502
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.1356
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.1415
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.1435
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.1478
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.1457
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 0.1506
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.1511
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.1335
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.1329
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 0.1459
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.1380
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.1248
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.1360
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1418
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.1481
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.1354
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.1437
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.1439
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.1471
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.1408
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.1430
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 0.1375
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.1358
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.1312
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.1541
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1352
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1358
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.1532
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 0.1236
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 0.1375
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 0.1322
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.1539
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.1326
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 0.1321
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.1347
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.1165
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1430
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.1448
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.1306
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.1445
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.1527
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.1463
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.1364
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.1444
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.1232
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.1357
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.1465
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.1200
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.1297
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.1313
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.1223
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.1372
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.1428
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.1286
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.1368
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.1391
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1269
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.1257
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 0.1201
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.1582
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 0.1123
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.1320
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.1288
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.1374
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 0.1313
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1472
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.1464
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.1132
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.1360
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 0.1223
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.1493
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.1335
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.1226
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.1339
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1255
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.1329
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.1301
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 0.1334
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.1337
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.1269
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.1123
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.1380
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1336
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.1441
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.1384
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.1196
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.1411
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.1221
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.1335
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1293
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.1345
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.1165
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.1358
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.1265
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.1283
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1366
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.1113
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.1316
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.1352
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 0.1302
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.1192
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.1393
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.1197
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.1311
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.1176
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 0.1463
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.1331
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1274
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.1157
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 0.1092
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.1260
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.1314
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.1204
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.1355
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.1215
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 0.1107
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.1325
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.1361
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 0.1195
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.1313
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.1148
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.1348
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.1341
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.1064
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.1037
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1021
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1213
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1224
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.1069
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.1126
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.1229
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.1199
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1225
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1353
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - loss: 0.1273
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.1296
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.1056
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.1256
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.1012
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.1137
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 0.1335
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1261
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.1145
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.1438
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.1069
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1239
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.1080
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1092
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.1270
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1101
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1117
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.1124
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.1108
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.1074
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.1145
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1087
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.1133
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.1306
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.1056
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.1212
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1070
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.1121
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.1054
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.1158
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.1203
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0979
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1152
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.1133
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.1240
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 0.1094
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 0.0929
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 0.1112
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0983
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.1126
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1265
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.1081
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.1116
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.1014
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 0.1068
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.1137
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0965
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1064
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 0.1108
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.1024
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.1114
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.1196
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.1030
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0994
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 0.1241
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.1191
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 0.1055
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.1150
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.1116
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.1037
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.1094
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 0.1187
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 0.1018
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.1175
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.1071
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.1067
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.1004
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.0915
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.1106
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.0955
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.1051
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 0.0970
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 0.1072
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.1074
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.1119
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.1214
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.1031
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.1037
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.1053
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - loss: 0.1099
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1169
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0934
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.1091
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0972
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 0.0958
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.0955
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 0.0919
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.0980
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1031
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.1067
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.1069
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.0884
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.1071
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 0.0975
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0964
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - loss: 0.0955
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0876
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0910
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.1082
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 0.0974
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.0933
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.1026
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0974
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.1009
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0867
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0905
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 0.1011
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 0.0888
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0882
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 0.0936
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0778
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.1063
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.1018
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 0.0992
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.1008
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 0.0894
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.0870
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0842
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - loss: 0.0863
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.0925
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.0923
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - loss: 0.0983
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.1058
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.0973
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0877
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.0906
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 0.1011
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 0.1108
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.1040
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0958
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0934
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0992
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0903
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - loss: 0.0922
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.0957
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 0.0863
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.0971
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.0910
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 0.0903
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.1042
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.1048
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.0836
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.0892
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0833
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.0924
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.1002
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.0882
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.0857
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.0927
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0914
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0968

# %%
y_predict_novo = regressor4.predict(x_treino_novo)
y_predict_teste_novo = regressor4.predict(x_teste_novo)
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x72db18280dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
resultado_treino = pd.DataFrame(y_predict_novo)[0]
resultado = pd.DataFrame(y_predict_teste_novo)[0]

# %%
sns.lineplot(x='tempo', y=y_treino_novo, data=passageiros[4:129], label='treino')
sns.lineplot(x='tempo', y=resultado_treino.values, data=passageiros[4:129], label='ajuste_treino')
sns.lineplot(x='tempo', y=y_teste_novo, data=passageiros[133:144], label='teste')
sns.lineplot(x='tempo', y=resultado.values, data=passageiros[133:144], label='previsão')
# Out:
# <Axes: xlabel='tempo'>

# %% [markdown]
# # 04.Redes recorrentes

# %%
bicicletas = pd.read_csv('bicicletas.csv')
bicicletas.head()
# Out:
#                  datas  contagem  temperatura  sensacao  umidade  vel_vento  \
# 0  2015-01-04 00:00:00       182          3.0       2.0     93.0        6.0
# 1  2015-01-04 01:00:00       138          3.0       2.5     93.0        5.0
# 2  2015-01-04 02:00:00       134          2.5       2.5     96.5        0.0
# 3  2015-01-04 03:00:00        72          2.0       2.0    100.0        0.0
# 4  2015-01-04 04:00:00        47          2.0       0.0     93.0        6.5
#
#    clima  feriado  final_ds  estacao
# 0    3.0      0.0       1.0      3.0
# 1    1.0      0.0       1.0      3.0
# 2    1.0      0.0       1.0      3.0
# 3    1.0      0.0       1.0      3.0
# 4    1.0      0.0       1.0      3.0

# %%
bicicletas['datas'] = pd.to_datetime(bicicletas['datas'])

# %%
plt.xticks(rotation=70)
sns.lineplot(x='datas', y='contagem', data=bicicletas)
# Out:
# <Axes: xlabel='datas', ylabel='contagem'>

# %%
sc2 = StandardScaler()
sc2.fit(bicicletas['contagem'].values.reshape(-1,1))
# Out:
# StandardScaler()

# %%
y = sc2.transform(bicicletas['contagem'].values.reshape(-1,1))

# %%
tamanho_treino = int(len(bicicletas) * 0.9)
tamanho_teste = len(bicicletas) - tamanho_treino

# %%
y_treino = y[0:tamanho_treino]
y_teste = y[tamanho_treino:len(bicicletas)]

# %%
plt.xticks(rotation=70)
sns.lineplot(x='datas', y=y_treino[:,0], data=bicicletas[0:tamanho_treino], label='treino')
sns.lineplot(x='datas', y=y_teste[:,0], data=bicicletas[tamanho_treino:len(bicicletas)], label='teste')
# Out:
# <Axes: xlabel='datas'>

# %%
vetor = pd.DataFrame(y_treino)[0]
x_treino_novo, y_treino_novo = separa_dados(vetor, 10)

# %%
vetor2 = pd.DataFrame(y_teste)[0]
x_teste_novo, y_teste_novo = separa_dados(vetor2, 10)

# %%
x_treino_novo = x_treino_novo.reshape((x_treino_novo.shape[0], x_treino_novo.shape[1], 1))
x_teste_novo = x_teste_novo.reshape((x_teste_novo.shape[0], x_teste_novo.shape[1], 1))

# %%
recorrente = Sequential([
    LSTM(128, input_shape=(x_treino_novo.shape[1], x_treino_novo.shape[2])),
    Dense(units=1)
])

recorrente.compile(loss='mean_squared_error', optimizer='RMSProp')

recorrente.summary()
# Out:
# /home/cristoffer_pogan/Documents/dev/Tutorials/Alura/Formacao_Machine_Learning_Avancada/Deep_Learning_Previsao_com_Keras/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,689 (260.50 KB)
#  Trainable params: 66,689 (260.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### LSTM = Long Short Term Memory
#
# [O que é uma LSTM?](https://cursos.alura.com.br/course/deep-learning-previsao-keras/task/78455)

# %% [markdown]
# # 05.Avaliando o resultado

# %%
resultado = recorrente.fit(x_treino_novo, y_treino_novo,
                           validation_data=(x_teste_novo, y_teste_novo), epochs=100)
# Out:
# Epoch 1/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4914 - val_loss: 0.1806
# Epoch 2/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0990 - val_loss: 0.0503
# Epoch 3/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0594 - val_loss: 0.0361
# Epoch 4/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0467 - val_loss: 0.0351
# Epoch 5/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0432 - val_loss: 0.0316
# Epoch 6/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0425 - val_loss: 0.0379
# Epoch 7/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0382 - val_loss: 0.0242
# Epoch 8/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0375 - val_loss: 0.0252
# Epoch 9/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0396 - val_loss: 0.0232
# Epoch 10/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0319 - val_loss: 0.0210
# Epoch 11/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0297 - val_loss: 0.0232
# Epoch 12/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0321 - val_loss: 0.0215
# Epoch 13/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0316 - val_loss: 0.0238
# Epoch 14/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0275 - val_loss: 0.0264
# Epoch 15/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0310 - val_loss: 0.0225
# Epoch 16/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0285 - val_loss: 0.0181
# Epoch 17/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0311 - val_loss: 0.0207
# Epoch 18/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0350 - val_loss: 0.0189
# Epoch 19/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0294 - val_loss: 0.0213
# Epoch 20/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0270 - val_loss: 0.0209
# Epoch 21/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0301 - val_loss: 0.0190
# Epoch 22/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0251 - val_loss: 0.0179
# Epoch 23/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0289 - val_loss: 0.0197
# Epoch 24/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0258 - val_loss: 0.0171
# Epoch 25/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0275 - val_loss: 0.0234
# Epoch 26/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0253 - val_loss: 0.0175
# Epoch 27/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0283 - val_loss: 0.0171
# Epoch 28/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0244 - val_loss: 0.0174
# Epoch 29/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0242 - val_loss: 0.0164
# Epoch 30/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0232 - val_loss: 0.0185
# Epoch 31/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0216 - val_loss: 0.0202
# Epoch 32/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0242 - val_loss: 0.0153
# Epoch 33/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0271 - val_loss: 0.0171
# Epoch 34/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0229 - val_loss: 0.0186
# Epoch 35/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0261 - val_loss: 0.0166
# Epoch 36/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0224 - val_loss: 0.0187
# Epoch 37/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0224 - val_loss: 0.0170
# Epoch 38/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0217 - val_loss: 0.0184
# Epoch 39/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0238 - val_loss: 0.0161
# Epoch 40/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0235 - val_loss: 0.0152
# Epoch 41/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0233 - val_loss: 0.0165
# Epoch 42/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0230 - val_loss: 0.0172
# Epoch 43/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0259 - val_loss: 0.0189
# Epoch 44/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0256 - val_loss: 0.0145
# Epoch 45/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0236 - val_loss: 0.0153
# Epoch 46/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0221 - val_loss: 0.0162
# Epoch 47/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0209 - val_loss: 0.0151
# Epoch 48/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0212 - val_loss: 0.0167
# Epoch 49/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0238 - val_loss: 0.0151
# Epoch 50/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0212 - val_loss: 0.0140
# Epoch 51/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0236 - val_loss: 0.0146
# Epoch 52/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0205 - val_loss: 0.0161
# Epoch 53/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0240 - val_loss: 0.0161
# Epoch 54/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0189 - val_loss: 0.0158
# Epoch 55/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0234 - val_loss: 0.0151
# Epoch 56/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0217 - val_loss: 0.0156
# Epoch 57/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0204 - val_loss: 0.0152
# Epoch 58/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0188 - val_loss: 0.0144
# Epoch 59/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0200 - val_loss: 0.0150
# Epoch 60/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0222 - val_loss: 0.0153
# Epoch 61/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0208 - val_loss: 0.0169
# Epoch 62/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0213 - val_loss: 0.0150
# Epoch 63/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0204 - val_loss: 0.0140
# Epoch 64/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0203 - val_loss: 0.0160
# Epoch 65/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0207 - val_loss: 0.0142
# Epoch 66/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0217 - val_loss: 0.0144
# Epoch 67/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0227 - val_loss: 0.0152
# Epoch 68/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0209 - val_loss: 0.0167
# Epoch 69/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0185 - val_loss: 0.0149
# Epoch 70/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0177 - val_loss: 0.0161
# Epoch 71/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0191 - val_loss: 0.0170
# Epoch 72/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0208 - val_loss: 0.0138
# Epoch 73/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0207 - val_loss: 0.0141
# Epoch 74/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0187 - val_loss: 0.0139
# Epoch 75/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0194 - val_loss: 0.0143
# Epoch 76/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0206 - val_loss: 0.0140
# Epoch 77/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0204 - val_loss: 0.0137
# Epoch 78/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0192 - val_loss: 0.0147
# Epoch 79/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0190 - val_loss: 0.0251
# Epoch 80/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0207 - val_loss: 0.0145
# Epoch 81/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0207 - val_loss: 0.0153
# Epoch 82/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0202 - val_loss: 0.0143
# Epoch 83/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0181 - val_loss: 0.0150
# Epoch 84/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0188 - val_loss: 0.0148
# Epoch 85/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0174 - val_loss: 0.0152
# Epoch 86/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0177 - val_loss: 0.0178
# Epoch 87/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0193 - val_loss: 0.0134
# Epoch 88/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0193 - val_loss: 0.0156
# Epoch 89/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0175 - val_loss: 0.0172
# Epoch 90/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0177 - val_loss: 0.0150
# Epoch 91/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0182 - val_loss: 0.0142
# Epoch 92/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0196 - val_loss: 0.0159
# Epoch 93/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0189 - val_loss: 0.0142
# Epoch 94/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0194 - val_loss: 0.0140
# Epoch 95/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0209 - val_loss: 0.0141
# Epoch 96/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0171 - val_loss: 0.0164
# Epoch 97/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0208 - val_loss: 0.0149
# Epoch 98/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0193 - val_loss: 0.0160
# Epoch 99/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0174 - val_loss: 0.0144
# Epoch 100/100
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0183 - val_loss: 0.0152

# %%
y_ajustado = recorrente.predict(x_treino_novo)
# Out:
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
plt.xticks(rotation=70)
sns.lineplot(x='datas', y=y_treino[:,0], data=bicicletas[0:tamanho_treino], label='treino')
sns.lineplot(x='datas', y=y_ajustado[:,0], data=bicicletas[0:15662], label='ajuste_treino')
# Out:
# <Axes: xlabel='datas'>

# %%
y_predito = recorrente.predict(x_teste_novo)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plt.xticks(rotation=70)
sns.lineplot(x='datas', y=y_teste[:,0], data=bicicletas[tamanho_treino:len(bicicletas)], label='teste')
sns.lineplot(x='datas', y=y_predito[:,0], data=bicicletas[tamanho_treino + 10:len(bicicletas)], label='previsão')
# Out:
# <Axes: xlabel='datas'>

# %%
recorrente_g = Sequential([
    GRU(128, input_shape=(x_treino_novo.shape[1], x_treino_novo.shape[2])),
    Dense(units=1)
])

recorrente_g.compile(loss='mean_squared_error', optimizer='RMSProp')

print(recorrente.summary())
print(recorrente_g.summary())
# Out:
# /home/cristoffer_pogan/Documents/dev/Tutorials/Alura/Formacao_Machine_Learning_Avancada/Deep_Learning_Previsao_com_Keras/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 133,380 (521.02 KB)
#  Trainable params: 66,689 (260.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 66,691 (260.52 KB)
# None
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 128)            │        50,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,433 (197.00 KB)
#  Trainable params: 50,433 (197.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
resultado2 = recorrente_g.fit(x_treino_novo, y_treino_novo,
                              validation_data=(x_teste_novo, y_teste_novo), epochs=100)

# %%
y_predito2 = recorrente_g.predict(x_teste_novo)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plt.xticks(rotation=70)
sns.lineplot(x='datas', y=y_teste[:,0], data=bicicletas[tamanho_treino:len(bicicletas)], label='teste')
sns.lineplot(x='datas', y=y_predito2[:,0], data=bicicletas[tamanho_treino + 10: len(bicicletas)], label='previsão')
# Out:
# <Axes: xlabel='datas'>

# %%
print(resultado2.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# LSTM
plt.plot(resultado.history['loss'])
plt.plot(resultado.history['val_loss'])
plt.legend(['treino', 'teste'])
plt.xlabel('Épocas')
plt.ylabel('Custo')
# Out:
# Text(0, 0.5, 'Custo')

# %%
# GRU
plt.plot(resultado2.history['loss'])
plt.plot(resultado2.history['val_loss'])
plt.legend(['treino', 'teste'])
plt.xlabel('Épocas')
plt.ylabel('Custo')
# Out:
# Text(0, 0.5, 'Custo')

# %% [markdown]
# ## Para saber mais: Otimizador
#
# Foi escolhido o RMSProp como otimizador dos pesos no treinamento da rede neural. O objetivo foi utilizar um otimizador _adaptivo_. Um otimizador adaptivo é capaz de controlar o gradiente e evitar que este cresça ou diminua muito. Entretanto, a escolha do RMSProp foi feita para chamar a atenção sobre o otimizador. Tanto o Adam quanto o RMSProp são adaptivos e seriam boas escolhas para a solução do problema.
#
# Para verificar outros otimizadores disponíveis no Keras você pode consultar este [link](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers).
